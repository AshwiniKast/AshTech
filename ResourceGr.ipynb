# %%
import os

# 1. Print ALL environment variables Python can actually see right now
print("--- ALL VISIBLE ENVIRONMENT VARIABLES ---")
for key, value in os.environ.items():
    if "AZURE" in key or "GROUP" in key: # Filter to keep it clean
        print(f"{key}: {value}")
print("-----------------------------------------")

# 2. Your original check
rg_name = "AzureML1" #os.environ.get("AZURE_RESOURCE_GROUP")
print(f"Direct lookup result: '{rg_name}'")

if not rg_name:
    raise ValueError("Critical Error: AZURE_RESOURCE_GROUP environment variable is not set!")
# Out:
# --- ALL VISIBLE ENVIRONMENT VARIABLES ---
# AZURE_EXTENSION_DIR: /opt/az/extensions
# CI_RESOURCE_GROUP: azureml1
# -----------------------------------------
# Direct lookup result: 'AzureML1'
